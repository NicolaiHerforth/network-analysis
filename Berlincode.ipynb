# %%
import numpy as np
import pandas as pd
import networkx as nx
import csv
import matplotlib.pyplot as plt

# %%
my_data = np.genfromtxt('RoadsData/BerlinNetwork.txt', skip_header = 9)
mylist = ['Init_node','Term_node','Capacity','Length','Free_Flow','Time','B','Power','Speed_limit','Toll','Type']
#~ 	Init node 	Term node 	Capacity 	Length 	Free Flow Time 	B 	Power 	Speed limit 	Toll 	Type 	;

# %%
my_data.shape
# Out:
# (28376, 11)

# %%
df = pd.DataFrame(my_data, columns= mylist)

# %%
df.mean()
# Out:
# Init_node        6147.635044
# Term_node        6151.203200
# Capacity       311679.333028
# Length            189.295038
# Free_Flow           5.380063
# Time                1.379335
# B                   4.000000
# Power               0.000000
# Speed_limit         0.000000
# Toll                0.689667
# Type                     NaN
# dtype: float64

# %%
df
# Out:
#        Init_node  Term_node  Capacity  Length  Free_Flow  Time    B  Power  \
# 0            1.0    11000.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 1            1.0    11007.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 2            1.0    11704.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 3            1.0    11708.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 4            1.0    11717.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 5            2.0    10892.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 6            2.0    10895.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 7            2.0    11707.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 8            2.0    11711.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 9            2.0    11714.0  999999.0     0.0        0.0   0.0  4.0    0.0
# 10           3.0     3336.0  999999.0     0.0        0.0   0.0  4.0    0.0
# ...

# %%
with open('edglist.csv', 'w') as csvfile:
    for items in my_data:
        csvfile.write(str(items[0]) + "," + str(items[1]) + "\n")

# %%
fh=open("edglist.csv", 'rb')
G=nx.read_edgelist(fh,delimiter = ",")

# %%
def read_graph(file_path):

    g = nx.DiGraph()
    file = open(file_path,'r')
    
    for line in file:
        split = line.split(',')
        n1 = int(float(split[0].strip()))
        n2 = int(float(split[1].strip()))
        capacity = float(split[2].strip())
        length = float(split[3].strip())
        free_flow_time = float(split[4].strip())
        b = float(split[5].strip())
        power = float(split[6].strip())
        speed_limit = float(split[7].strip())
        toll = float(split[8].strip())
        edge_type = float(split[9].strip())
        
        if n1 not in g.nodes():
            g.add_node(n1, color = 'b', size = 50)
        
        if n2 not in g.nodes():
            g.add_node(n2,color='b', size=50)
        
        g.add_edge(n1,
                   n2,
                   capacity=capacity,
                   length=length, 
                   free_flow_time=free_flow_time,
                   b=b,
                   power=power,
                   speed_limit=speed_limit,
                   toll=toll,
                   edge_type=edge_type)
            
    file.close()
    return g

# %%
graph = read_graph("RoadsData/mitte-center-network.txt")

#nodes = []
#edges = {}
#file = open("edglist.csv",'r')

#for line in file:
#    split = line.split(',')
#    n1 = int(float(split[0].strip()))
#    n2 = int(float(split[1].strip()))
#    graph.add_edge(n1,n2)
            
#file.close()

#color = nx.get_node_attributes(graph,'color')
#size = nx.get_node_attributes(graph,'size')

#nx.draw(graph,
#        node_size= 0,
#        width=0.04,
#        with_labels=False)
#plt.show(graph)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-0cdee328ced8> in <module>()
# ----> 1 graph = read_graph("RoadsData/mitte-center-network.txt")
#       2
#       3 #nodes = []
#       4 #edges = {}
#       5 #file = open("edglist.csv",'r')
#
# <ipython-input-16-5d7b562bd590> in read_graph(file_path)
#       6     for line in file:
#       7         split = line.split(',')
# ----> 8         n1 = int(float(split[0].strip()))
#       9         n2 = int(float(split[1].strip()))
#      10         capacity = float(split[2].strip())
#
# ValueError: could not convert string to float: '<NUMBER OF ZONES> 36'
